# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 4

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %% [markdown]
# Importing necessary libraries

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\lib\site-packages (4.1.3)
# Requirement already satisfied: trio-websocket~=0.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: async-generator>=1.9 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\programdata\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
# Importing all the required libraries
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time
from bs4 import BeautifulSoup
import re
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException,ElementNotInteractableException
from selenium.webdriver.support.ui import WebDriverWait

# %%
# Connecting to the webdriver
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(3)

# Getting the webpage of mentioned url 
url=('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
driver.get(url)

# %%
# Creating empty list for scaping the data

Rank = []
Name = []
Artist = []
Upload_Date = []
Views = []

# %%
# Scraping Rank of the videos
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# Scraoing Name of the videos
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("_")
    
# Scraping Artist of the video
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("_")

# Scraping Uploaded date of the video
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("_")
# Scraping Views of videos
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        Upload_Date.append(i.text)
except NoSuchElementException:
    Upload_Date.append("_")
    
# Creating DataFrame fr scraped data
Wiki = pd.DataFrame({})
Wiki['Rank']=Rank
Wiki['Name']=Name
Wiki['Artist']=Artist
Wiki['Upload Date']=Upload_Date
Wiki['Views(billions)']=Views

# Removing stray numbers from Name column
Wiki.Name = Wiki.Name.apply(lambda x:x[:-4].strip('"'))
Wiki
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.                Phonics Song with Two Words
# 7    8.                                Uptown Funk
# 8    9.  Learning Colors – Colorful Eggs on a Farm
# 9   10.   Masha and the Bear – Recipe for Disaster
# 10  11.                              Gangnam Style
# 11  12.                          Wheels on the Bus
# 12  13.                             Dame Tu Cosita
# 13  14.                                      Sugar
# 14  15.                                       Roar
# 15  16.                             Counting Stars
# 16  17.                                      Sorry
# 17  18.                          Thinking Out Loud
# 18  19.                                     Axel F
# 19  20.                             Girls Like You
# 20  21.                                      Faded
# 21  22.                                 Dark Horse
# 22  23.                        Baa Baa Black Sheep
# 23  24.                                 Let Her Go
# 24  25.                                   Bailando
# 25  26.                                    Lean On
# 26  27.                                    Perfect
# 27  28.                               Shake It Off
# 28  29.           Waka Waka (This Time for Africa)
# 29  30.                                   Mi Gente
# 30   1.                           Baby Shark Dance
# 31   2.                                  Despacito
# 32   3.                       Johny Johny Yes Papa
# 33   4.                               Shape of You
# 34   5.                              See You Again
# 35   6.                                  Bath Song
# 36   7.                Phonics Song with Two Words
# 37   8.                                Uptown Funk
# 38   9.  Learning Colors – Colorful Eggs on a Farm
# 39  10.   Masha and the Bear – Recipe for Disaster
# 40  11.                              Gangnam Style
# 41  12.                          Wheels on the Bus
# 42  13.                             Dame Tu Cosita
# 43  14.                                      Sugar
# 44  15.                                       Roar
# 45  16.                             Counting Stars
# 46  17.                                      Sorry
# 47  18.                          Thinking Out Loud
# 48  19.                                     Axel F
# 49  20.                             Girls Like You
# 50  21.                                      Faded
# 51  22.                                 Dark Horse
# 52  23.                        Baa Baa Black Sheep
# 53  24.                                 Let Her Go
# 54  25.                                   Bailando
# 55  26.                                    Lean On
# 56  27.                                    Perfect
# 57  28.                               Shake It Off
# 58  29.           Waka Waka (This Time for Africa)
# 59  30.                                   Mi Gente
#
#                                          Artist        Upload Date  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                    Luis Fonsi   January 12, 2017
# 2                                   LooLoo Kids    October 8, 2016
# 3                                    Ed Sheeran   January 30, 2017
# 4                                   Wiz Khalifa      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                     ChuChu TV      March 6, 2014
# 7                                   Mark Ronson  November 19, 2014
# 8                                   Miroshka TV  February 27, 2018
# 9                                    Get Movies   January 31, 2012
# 10                                          Psy      July 15, 2012
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018
# 12                                    El Chombo      April 5, 2018
# 13                                     Maroon 5   January 14, 2015
# 14                                   Katy Perry  September 5, 2013
# 15                                  OneRepublic       May 31, 2013
# 16                                Justin Bieber   October 22, 2015
# 17                                   Ed Sheeran    October 7, 2014
# 18                                   Crazy Frog      June 16, 2009
# 19                                     Maroon 5       May 31, 2018
# 20                                  Alan Walker   December 3, 2015
# 21                                   Katy Perry  February 20, 2014
# 22                   Cocomelon – Nursery Rhymes      June 25, 2018
# 23                                    Passenger      July 25, 2012
# 24                             Enrique Iglesias     April 11, 2014
# 25                                  Major Lazer     March 22, 2015
# 26                                   Ed Sheeran   November 9, 2017
# 27                                 Taylor Swift    August 18, 2014
# 28                                      Shakira       June 4, 2010
# 29                                     J Balvin      June 29, 2017
# 30  Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 31                                   Luis Fonsi   January 12, 2017
# 32                                  LooLoo Kids    October 8, 2016
# 33                                   Ed Sheeran   January 30, 2017
# 34                                  Wiz Khalifa      April 6, 2015
# 35                   Cocomelon – Nursery Rhymes        May 2, 2018
# 36                                    ChuChu TV      March 6, 2014
# 37                                  Mark Ronson  November 19, 2014
# 38                                  Miroshka TV  February 27, 2018
# 39                                   Get Movies   January 31, 2012
# 40                                          Psy      July 15, 2012
# 41                   Cocomelon – Nursery Rhymes       May 24, 2018
# 42                                    El Chombo      April 5, 2018
# 43                                     Maroon 5   January 14, 2015
# 44                                   Katy Perry  September 5, 2013
# 45                                  OneRepublic       May 31, 2013
# 46                                Justin Bieber   October 22, 2015
# 47                                   Ed Sheeran    October 7, 2014
# 48                                   Crazy Frog      June 16, 2009
# 49                                     Maroon 5       May 31, 2018
# 50                                  Alan Walker   December 3, 2015
# 51                                   Katy Perry  February 20, 2014
# 52                   Cocomelon – Nursery Rhymes      June 25, 2018
# 53                                    Passenger      July 25, 2012
# 54                             Enrique Iglesias     April 11, 2014
# 55                                  Major Lazer     March 22, 2015
# 56                                   Ed Sheeran   November 9, 2017
# 57                                 Taylor Swift    August 18, 2014
# 58                                      Shakira       June 4, 2010
# 59                                     J Balvin      June 29, 2017
#
#    Views(billions)
# 0            10.80
# 1             7.87
# 2             6.37
# 3             5.74
# 4             5.54
# 5             5.44
# 6             4.67
# 7             4.60
# 8             4.58
# 9             4.50
# 10            4.45
# 11            4.12
# 12            3.95
# 13            3.71
# 14            3.60
# 15            3.59
# 16            3.55
# 17            3.46
# 18            3.38
# 19            3.30
# 20            3.29
# 21            3.29
# 22            3.26
# 23            3.24
# 24            3.22
# 25            3.22
# 26            3.18
# 27            3.18
# 28            3.16
# 29            3.09
# 30           10.80
# 31            7.87
# 32            6.37
# 33            5.74
# 34            5.54
# 35            5.44
# 36            4.67
# 37            4.60
# 38            4.58
# 39            4.50
# 40            4.45
# 41            4.12
# 42            3.95
# 43            3.71
# 44            3.60
# 45            3.59
# 46            3.55
# 47            3.46
# 48            3.38
# 49            3.30
# 50            3.29
# 51            3.29
# 52            3.26
# 53            3.24
# 54            3.22
# 55            3.22
# 56            3.18
# 57            3.18
# 58            3.16
# 59            3.09

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through cod

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(3)

# %%
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

# %%
button=driver.find_element_by_xpath('//button[@class="cookie__accept btn btn-primary"]')
button.click()

# %%
# click on "International" button to expand it
driver.find_element_by_xpath("/html/body/nav/div[1]/div[2]/ul[1]/li[2]").click()

# %%
# click on 'Fixtures'
driver.find_element_by_xpath("/html/body/div[2]/div[1]/div/ul/li[1]").click()

# %%
# click on 'More Fixtures'
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button').click()

# %%
#Creating Empty Listmatch = []
match = []
series = []
place = []
date = []
time = []

# %%
try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding"]'):
        match.append(i.text)
except NoSuchElementException:
    match.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]'):
        series.append(i.text.split('-')[0])
except NoSuchElementException:
    series.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]'):
        place.append(i.text)
except NoSuchElementException:
    place.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//h5[@class="ng-binding"]'):
        date.append(i.text)
except NoSuchElementException:
    date.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//h5[@class="text-right ng-binding"]'):
        time.append(i.text)
except NoSuchElementException:
    time.append("-")

# %%
df = pd.DataFrame({'Match Title':match,'Series':series,'Venue':place,'Date':date,'time':time})
df
# Out:
#                                      Match Title     Series  \
# 0  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  1st T20I
# 1  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  2nd T20I
# 2          INDIA TOUR OF IRELAND T20 SERIES 2022  1st T20I
# 3  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  3rd T20I
# 4          INDIA TOUR OF IRELAND T20 SERIES 2022  2nd T20I
# 5  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   1st ODI
# 6         INDIA TOUR OF ENGLAND TEST SERIES 2021  5th Test
# 7  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   2nd ODI
#
#                                       Venue         Date          time
# 0   Rangiri Dambulla International Stadium,  23 JUN 2022   2:30 PM IST
# 1   Rangiri Dambulla International Stadium,  25 JUN 2022   2:30 PM IST
# 2                              The Village,  26 JUN 2022   9:00 PM IST
# 3   Rangiri Dambulla International Stadium,  27 JUN 2022   2:30 PM IST
# 4                              The Village,  28 JUN 2022   9:00 PM IST
# 5  Pallekele International Cricket Stadium,   1 JUL 2022  10:00 AM IST
# 6                                Edgbaston,   1 JUL 2022   3:30 PM IST
# 7  Pallekele International Cricket Stadium,   4 JUL 2022  10:00 AM IST

# %%
driver.close()

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(3)

# %%
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(2)

# %%
search_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
search_bar.send_keys("selenium exception handling")
search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button")
search_btn.click()
time.sleep(2)

# %%
link = driver.find_element_by_xpath('//div[@class="gsc-expansionArea"]//div//a')
page_links = link.get_attribute("href")

driver.get(page_links)
time.sleep(3)

Name = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[1]')[1:]:
    Name.append(i.text)
    
Description = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[2]')[1:]:
    Description.append(i.text)

# %%
df = pd.DataFrame({'Name':Name,'Description':Description})
df
# Out:
#                                    Name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                           Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %%
driver.close()

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
driver= webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.statisticstimes.com/"
driver.get(url)

# %%
economy = driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
economy.click()
india = driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
india.click()
time.sleep(2)

GDP_india = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP_india.click()
time.sleep(3)

# %%
rank = []
state = []
GSDP = []
GSDP1 = []
share = []
GDP = []

# %%
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[1]'):
    rank.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[2]'):
    state.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[3]'):
    GSDP.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[4]'):
    GSDP1.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[5]'):
    share.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[6]'):
    GDP.append(i.text)

# %%
df = pd.DataFrame({'Rank':rank,'State':state,'GSDP(19-20)':GSDP,'GSDP(18-19)':GSDP1,'Share':share,'GDP':GDP})
df
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19)   Share      GDP
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# 5     6                West Bengal   1,253,832   1,089,898   5.77%  165.556
# 6     7                  Rajasthan   1,020,989     942,586   4.99%  143.179
# 7     8             Andhra Pradesh     972,782     862,957   4.57%  131.083
# 8     9                  Telangana     969,604     861,031   4.56%  130.791
# 9    10             Madhya Pradesh     906,672     809,592   4.29%  122.977
# 10   11                     Kerala           -     781,653   4.14%  118.733
# 11   12                      Delhi     856,112     774,870   4.10%  117.703
# 12   13                    Haryana     831,610     734,163   3.89%  111.519
# 13   14                      Bihar     611,804     530,363   2.81%   80.562
# 14   15                     Punjab     574,760     526,376   2.79%   79.957
# 15   16                     Odisha     521,275     487,805   2.58%   74.098
# 16   17                      Assam           -     315,881   1.67%   47.982
# 17   18               Chhattisgarh     329,180     304,063   1.61%   46.187
# 18   19                  Jharkhand     328,598     297,204   1.57%   45.145
# 19   20                Uttarakhand           -     245,895   1.30%   37.351
# 20   21            Jammu & Kashmir           -     155,956   0.83%   23.690
# 21   22           Himachal Pradesh     165,472     153,845   0.81%   23.369
# 22   23                        Goa      80,449      73,170   0.39%   11.115
# 23   24                    Tripura      55,984      49,845   0.26%    7.571
# 24   25                 Chandigarh           -      42,114   0.22%    6.397
# 25   26                 Puducherry      38,253      34,433   0.18%    5.230
# 26   27                  Meghalaya      36,572      33,481   0.18%    5.086
# 27   28                     Sikkim      32,496      28,723   0.15%    4.363
# 28   29                    Manipur      31,790      27,870   0.15%    4.233
# 29   30                   Nagaland           -      27,283   0.14%    4.144
# 30   31          Arunachal Pradesh           -      24,603   0.13%    3.737
# 31   32                    Mizoram      26,503      22,287   0.12%    3.385
# 32   33  Andaman & Nicobar Islands           -           -       -        -

# %%
driver.close()

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#Activating the chrome browser
driver = webdriver.Chrome("chromedriver.exe")

# %%
#getting the specified url
url = "https://github.com/"
driver.get(url)
time.sleep(3)

# %%
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
#Creating empty list
repo_urls = []
rep_title = []
Description = []
Contributors = []
Language = []
lang = []

# %%
#Fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    repo_urls.append(i.get_attribute("href"))

    
#Scraping data of repository title
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    rep_title.append(i.text)

    
#Scraping data from every repository page
for i in repo_urls:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping data of decription
    try:
        desc = driver.find_element_by_xpath("//p[@cclass='col-9 color-fg-muted my-1 pr-4']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    #Scraping data of contributors
    try:
        cont_tags = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(cont_tags.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
     #fetching Languages used
    try:
        for i in driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')

# %%
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = rep_title[:50]
Github['Repository description'] = Description[:50]
Github['Contributors count'] = Contributors[:50]
Github['Language used'] = Language[:50]

# %%
#Printing data frame
Github
# Out:
#                                Repository title Repository description  \
# 0                         mingrammer / diagrams                      -
# 1                             hashicorp / nomad                      -
# 2                            facebook / lexical                      -
# 3   girliemac / a-picture-is-worth-a-1000-words                      -
# 4                         WenchaoD / FSCalendar                      -
# 5                           PrefectHQ / prefect                      -
# 6                        Reiten966 / Polyformer                      -
# 7                               hashicorp / hcl                      -
# 8              pittcsc / Summer2023-Internships                      -
# 9                Technawi / SOC-Analyst-Diploma                      -
# 10                               apache / hbase                      -
# 11                           codeedu / imersao8                      -
# 12                               go-gorm / gorm                      -
# 13                           elixir-ecto / ecto                      -
# 14                           milvus-io / milvus                      -
# 15                            knative / serving                      -
# 16                   Azure / azure-sdk-for-java                      -
# 17                        Alamofire / Alamofire                      -
# 18                  OAI / OpenAPI-Specification                      -
# 19    terraform-aws-modules / terraform-aws-alb                      -
# 20                          google / googletest                      -
# 21                          fastlane / fastlane                      -
# 22                    sourcegraph / sourcegraph                      -
# 23                    woocommerce / woocommerce                      -
# 24                  firebase / firebase-ios-sdk                      -
# 25                        mingrammer / diagrams                      -
# 26                            hashicorp / nomad                      -
# 27                           facebook / lexical                      -
# 28  girliemac / a-picture-is-worth-a-1000-words                      -
# 29                        WenchaoD / FSCalendar                      -
# 30                          PrefectHQ / prefect                      -
# 31                       Reiten966 / Polyformer                      -
# 32                              hashicorp / hcl                      -
# 33             pittcsc / Summer2023-Internships                      -
# 34               Technawi / SOC-Analyst-Diploma                      -
# 35                               apache / hbase                      -
# 36                           codeedu / imersao8                      -
# 37                               go-gorm / gorm                      -
# 38                           elixir-ecto / ecto                      -
# 39                           milvus-io / milvus                      -
# 40                            knative / serving                      -
# 41                   Azure / azure-sdk-for-java                      -
# 42                        Alamofire / Alamofire                      -
# 43                  OAI / OpenAPI-Specification                      -
# 44    terraform-aws-modules / terraform-aws-alb                      -
# 45                          google / googletest                      -
# 46                          fastlane / fastlane                      -
# 47                    sourcegraph / sourcegraph                      -
# 48                    woocommerce / woocommerce                      -
# 49                  firebase / firebase-ios-sdk                      -
#
#    Contributors count Language used
# 0                 104            []
# 1                 556            []
# 2                  98            []
# 3                   2            []
# 4                  22            []
# 5                 311            []
# 6                   3            []
# 7                  72            []
# 8                 219            []
# 9                   -            []
# 10                377            []
# 11                  2            []
# 12                305            []
# 13                662            []
# 14                183            []
# 15                242            []
# 16                454            []
# 17                240            []
# 18                198            []
# 19                 49            []
# 20                356            []
# 21              1,221            []
# 22                274            []
# 23              1,165            []
# 24                177            []
# 25                104            []
# 26                556            []
# 27                 98            []
# 28                  2            []
# 29                 22            []
# 30                311            []
# 31                  3            []
# 32                 72            []
# 33                219            []
# 34                  -            []
# 35                377            []
# 36                  2            []
# 37                305            []
# 38                662            []
# 39                183            []
# 40                242            []
# 41                454            []
# 42                240            []
# 43                198            []
# 44                 49            []
# 45                356            []
# 46              1,221            []
# 47                274            []
# 48              1,165            []
# 49                177            []

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Connecting to the webdriver
driver = webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=('https://www.billboard.com/')
driver.get(url)

# %%
menu=driver.find_element_by_xpath("/html/body/div[3]/header/div[1]/div/div/div[1]/button").click()

# %%
list=driver.find_element_by_xpath("/html/body/div[3]/div[6]/div/div/div/ul/li[1]/h3/button").click()

# %%
#Clicking on charts
charts=driver.find_element_by_xpath("/html/body/div[3]/div[6]/div/div/div/ul/li[1]/ul/li[2]").click()

# %%
# Creating empty lists
Song_Name = []
Artist_Name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# Getting urls for top 100 songs
urls = driver.find_element_by_xpath("/html/body/div[3]/main/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div[2]/h3/a")
page_url = urls.get_attribute("href")
driver.get(page_url)
time.sleep(4)

# Scraping data of song names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    
# Scraping data of artist names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    
# Scraping data of last week ranks
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    
# Scraping data of peak rank
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)
    
# Scraping data of weeks on board
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
# Creating dataframe for scraped data
billboard=pd.DataFrame({})
billboard['Name'] = Song_Name
billboard['Artist'] = Artist_Name
billboard['Last week rank'] = Last_week_rank
billboard['Peak rank'] = Peak_rank
billboard['Weeks on board'] = Weeks_on_board
billboard
# Out:
# Empty DataFrame
# Columns: [Name, Artist, Last week rank, Peak rank, Weeks on board]
# Index: []

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# Connecting to the webdriver
driver = webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=('https://www.naukri.com/browse-jobs')
driver.get(url)
time.sleep(2)

# %%
#Fetching urls to navigate recruiter page
recruiter = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                Sakshi Chhikara
# 17                                    Ruchi Dhote
# 18                                  Manisha Yadav
# 19                                    Riya Rajesh
# 20                           Rashmi Bhattacharjee
# 21                                  Faizan Kareem
# 22                                 Rithika dadwal
# 23                             Sandhya Khandagale
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                      Jayanth N
# 32                                         Avodha
# 33                                    Priya Khare
# 34                                    Amit Sharma
# 35                                          Kanan
# 36                           Shashikant Chaudhary
# 37                                           Brad
# 38                                   Rutuja Pawar
# 39                            Madhusudhan Sridhar
# 40                                    Ankit Sinha
# 41                                 Gaurav Chouhan
# 42                                   Rashi Kacker
# 43                                        Ashwini
# 44                                   Balaji Kolli
# 45                                 Rajani Nagaraj
# 46                                    ROHIT Kumar
# 47                                 Amir Chowdhury
# 48                                       SREEDHAR
# 49                                   Sunny Sharma
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                           HR Manager
# 16                 Assistant Manager HR
# 17  Senior Executive Talent Acquisition
# 18                         HR Executive
# 19           Manager Talent Acquisition
# 20                              HR Head
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31                      Project Manager
# 32       Business Development Associate
# 33                       Senior Manager
# 34                           Consultant
# 35         senior technology instructor
# 36             HR Recruiter/HR Excutive
# 37        Manager, Technical Recruiting
# 38                  Technical Recruiter
# 39                      Erp Implementer
# 40                       Head Analytics
# 41              Chief Technical Officer
# 42                   Sr Product Manager
# 43             Director Global Delivery
# 44                           Co Founder
# 45                           HR Manager
# 46                            Architect
# 47                     Managing Partner
# 48               Recruitment Consultant
# 49               Managing Director - HR
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                               SocialPrachar.com
# 15                                  BISP Solutions
# 16                   BIZ INFOTECNO PRIVATE LIMITED
# 17                           Bristlecone India Ltd
# 18                                        Easi Tax
# 19                     Novelworx Digital Solutions
# 20         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 21                   FirstTech Consaltants Pvt.Ltd
# 22                                Affine Analytics
# 23                 Compumatrice Multimedia Pvt Ltd
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31        Dollarbird Information Services Pvt, Ltd
# 32                              Nikitha Palaparthi
# 33                          Independent Consultant
# 34                                 ASCO consulting
# 35                                         NY INST
# 36  3D India Staffing Research &amp; Consulting...
# 37                                     O.C. Tanner
# 38                                   Demand Matrix
# 39                             MADHUSUDHAN SRIDHAR
# 40                                  Suntech Global
# 41                        Strategic Consulting Lab
# 42                            Impel Labs Pvt. Ltd.
# 43                                    MRP Advisers
# 44                   Saras Solutions India Pvt Ltd
# 45                                     WildJasmine
# 46                             LNT Private Limited
# 47                                     Granular.ai
# 48     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 49                       Western Service Providers
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15     Big Data, Hadoop, Data Analytics, Data Science
# 16  React.js, Data Science, Java, Front End, Busin...
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Telecalling, Client Interaction, Marketing, Re...
# 19                                       Data Science
# 20  Corporate Sales, Software Development, Softwar...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Big Data, Data Science, Artificial Intelligenc...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Data Analytics, Managed Services, Team Leading...
# 32  Ethical Hacking, Security Operations Center, S...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  Data Science, Machine Learning, Big Data Analy...
# 49  Software Professionals, Engineering, Technical...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                 Priyanka Akiri
# 31                                     HR Manager
# 32                                      Hyderabad
# 33                                Kalpana Dumpala
# 34                               Executive Hiring
# 35                       Hyderabad / Secunderabad
# 36                                        Mubarak
# 37                                     Company HR
# 38                          Bengaluru / Bangalore
# 39                                 Kushal Rastogi
# 40                                     Company HR
# 41                                         Mumbai
# 42                             Mahesh Babu Channa
# 43                                   HR Team Lead
# 44                       Hyderabad / Secunderabad
# 45                                   Kapil Devang
# 46                                     HR Manager
# 47                                         Bhopal
# 48                                Sakshi Chhikara
# 49                           Assistant Manager HR

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Connecting to the webdriver
driver = webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
driver.get(url)

# %%
#Creating empty list
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

#scraping book names data
for i in driver.find_elements_by_xpath("//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping author names data
for i in driver.find_elements_by_xpath("//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements_by_xpath("//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements_by_xpath("//tbody/tr/td[5]"):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//tbody/tr/td[6]"):
    Genre.append(i.text)
    
#Creating dataframe for scraped data
Novels=pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Connecting to the webdriver
driver = webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=("https://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
    
# Creating dataframe for scraped data
TV_series=pd.DataFrame({})
TV_series['Name'] = Name
TV_series['Year Span'] = Year_span
TV_series['Genre'] = Genre
TV_series['Run Time'] = Run_time
TV_series['Ratings'] = Ratings
TV_series['Votes'] = Votes
TV_series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,000,873
# 1    51 min     8.7  1,053,125
# 2    44 min     8.2    951,914
# 3    60 min     7.5    284,504
# 4    43 min     7.6    244,277
# ..      ...     ...        ...
# 95   42 min     7.4     48,981
# 96   50 min     7.8     59,714
# 97   42 min     8.1    191,187
# 98   45 min     7.1     40,428
# 99  572 min     8.6    229,848
#
# [100 rows x 6 columns]

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
# Connecting to the webdriver
driver = webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=("https://archive.ics.uci.edu/")
driver.get(url)

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element_by_xpath("//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(2)
    
    #Scraping data type
    try:
        data_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(2)
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(2)
    
     # Scraping Attribute type
    try:
        attribute_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(2)
    
    # Scraping No of instances
    try:
        instances = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(2)
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(2)
    
    # Scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4948/4102260654.py in <module>
#       9
#      10 for i in urls:
# ---> 11     driver.get(i)
#      12     time.sleep(3)
#      13
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from disconnected: Unable to receive message from renderer
#   (Session info: chrome=102.0.5005.115)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0124B8F3+2406643]
# 	Ordinal0 [0x011DAF31+1945393]
# 	Ordinal0 [0x010CC748+837448]
# 	Ordinal0 [0x010BDA12+776722]
# 	Ordinal0 [0x010BC7C5+772037]
# 	Ordinal0 [0x010BCDC8+773576]
# 	Ordinal0 [0x010BCD58+773464]
# 	Ordinal0 [0x010C29B6+797110]
# 	Ordinal0 [0x010C2CEA+797930]
# 	Ordinal0 [0x010BDF9B+778139]
# 	Ordinal0 [0x010BE4C5+779461]
# 	Ordinal0 [0x010BE2AF+778927]
# 	Ordinal0 [0x010BD8A6+776358]
# 	Ordinal0 [0x010BC7C5+772037]
# 	Ordinal0 [0x010BCDC8+773576]
# 	Ordinal0 [0x010C8BE0+822240]
# 	Ordinal0 [0x010BE0BD+778429]
# 	Ordinal0 [0x010BEC9A+781466]
# 	Ordinal0 [0x010BE2CA+778954]
# 	Ordinal0 [0x010BD8A6+776358]
# 	Ordinal0 [0x010BC7C5+772037]
# 	Ordinal0 [0x010BCC9D+773277]
# 	Ordinal0 [0x010CDF4A+843594]
# 	Ordinal0 [0x01124D3D+1199421]
# 	Ordinal0 [0x0111427C+1131132]
# 	Ordinal0 [0x01124682+1197698]
# 	Ordinal0 [0x01114096+1130646]
# 	Ordinal0 [0x010EE636+976438]
# 	Ordinal0 [0x010EF546+980294]
# 	GetHandleVerifier [0x014B9612+2498066]
# 	GetHandleVerifier [0x014AC920+2445600]
# 	GetHandleVerifier [0x012E4F2A+579370]
# 	GetHandleVerifier [0x012E3D36+574774]
# 	Ordinal0 [0x011E1C0B+1973259]
# 	Ordinal0 [0x011E6688+1992328]
# 	Ordinal0 [0x011E6775+1992565]
# 	Ordinal0 [0x011EF8D1+2029777]
# 	BaseThreadInitThunk [0x76FEFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77817A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77817A6E+238]

# %%
# Creating dataframe for scraped data
ML=pd.DataFrame({})
ML['Data Name'] = Dataset_name
ML['Data Type'] = Data_type
ML['Task'] = Task
ML['Attribute type'] = Attribute_type
ML['No of instance'] = No_of_instances
ML['No of attributes'] = No_of_attributes
ML['Year'] = Year
ML
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 342         MiniBooNE particle identification Data Set
# 343                    Miskolc IIS Hybrid IPS Data Set
# 344                             Mobile Robots Data Set
# 345                       MoCap Hand Postures Data Set
# 346  Molecular Biology (Promoter Gene Sequences) Da...
#
#                      Data Type                                          Task  \
# 0                 Multivariate                                Classification
# 1             Sequential, Text                        Regression, Clustering
# 2    Multivariate, Time-Series                    Classification, Clustering
# 3                   Sequential                    Classification, Regression
# 4                 Multivariate                    Classification, Clustering
# ..                         ...                                           ...
# 342               Multivariate                                Classification
# 343                       Text  Classification, Clustering, Causal-Discovery
# 344              Domain-Theory                                             -
# 345               Multivariate                    Classification, Clustering
# 346  Sequential, Domain-Theory                                Classification
#
#                  Attribute type No of instance No of attributes  Year
# 0                          Real           7840                5  2018
# 1                          Real         434874                4  2013
# 2                 Integer, Real           1984                8  2019
# 3                          Real         158716                4  2021
# 4                             -            232               16  2020
# ..                          ...            ...              ...   ...
# 342                        Real         130065               50  2010
# 343                     Integer           1540               67  2016
# 344  Categorical, Integer, Real              -                -  1995
# 345               Integer, Real          78095               38  2016
# 346                 Categorical            106               58  1990
#
# [347 rows x 7 columns]
